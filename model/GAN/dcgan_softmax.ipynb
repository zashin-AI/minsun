# %% [markdown]
# # 모두의 딥러닝 20_GAN

# %% [markdown]
# https://github.com/gilbutITbook/080228/blob/master/deeplearning/run_project/20_GAN.ipynb

# %%
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler

import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

import librosa
import librosa.display
import soundfile as sf

# %%
#이미지가 저장될 폴더가 없다면 만듭니다.
# import os
# if not os.path.exists("E:\\nmb\\gan_images"):
#     os.makedirs("E:\\nmb\\gan_image")

np.random.seed(3)
tf.random.set_seed(3)

nosie_size = 100
x_size = 32
y_size = 128
gx1 = int(x_size/4)
gy1 = int(y_size/4)

epochs = 300001
batch = 16

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*gx1*gy1, input_dim=nosie_size, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((gx1, gy1, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32768)             3309568
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32768)             131072
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 32, 128)        0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 16, 64, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 64, 64)        204864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 64, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 16, 64, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 32, 128, 64)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 128, 1)        1601
# =================================================================
# Total params: 3,647,361
# Trainable params: 3,581,697
# Non-trainable params: 65,664
# _________________________________________________________________

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(x_size,y_size,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='softmax'))

# compile
discriminator.compile(loss='categorical_crossentropy', optimizer='adam')
# discriminator.trainable = False
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 16, 64, 64)        1664
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 64, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 64, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 32, 128)        204928
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 32, 128)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 32, 128)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 32769
# =================================================================
# Total params: 239,361
# Trainable params: 239,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
discriminator.trainable = False
ginput = Input(shape=(nosie_size,))                    
dis_output = discriminator(generator(ginput))         
gan = Model(ginput, dis_output)
gan.compile(loss='categorical_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 32, 128, 1)        3647361
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 239361
# =================================================================
# Total params: 3,886,722
# Trainable params: 3,581,697
# Non-trainable params: 305,025
# _________________________________________________________________

# %%
# X_train = np.load('E:\\nmb\\nmb_data\\npy\\1m2s\\concate\\total_fm_data.npy')
X_train = np.load('C:\\nmb\\nmb_data\\npy\\total_f_data.npy')
print(X_train.shape)    # (2331, 128, 862)

x_train= []
for i in range (X_train.shape[0]) : 
    print(X_train[i].shape)
    img_resize = cv2.resize(X_train[i], (x_size, y_size))
    print(img_resize.shape)
    x_train.append(img_resize)
    
x_train = np.array(x_train)
x_train.shape    # (2331, 128, 32)
# Out:
# 28, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (2331, 128, 32)

# %%
from datetime import datetime
start = datetime.now()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):
  
  global nosie_size, x_size, y_size


  # 데이터 불러오기
  print(x_train.shape)  # (2331, 128, 32)
  X_train = x_train.reshape(x_train.shape[0], x_size*y_size).astype('float32')
  print(np.max(X_train), np.min(X_train))   # -0.00016182661 -80.0

  scale = MaxAbsScaler()
    #   절대값이 0~1사이에 매핑
    #   -1 ~ 1 사이로 재조정
  X_train = scale.fit_transform(X_train)
  print(X_train.shape)   # (2331, 4096)
  print(np.max(X_train), np.min(X_train))   # -2.0228326e-06 -1.0


  X_train = X_train.reshape(x_train.shape[0], x_size, y_size, 1).astype('float32')
  print(X_train.shape)  # (2331, 32, 128, 1)

  true = np.ones((batch_size, 1))   # 1로 라벨링
    # print(true.shape)     # (32, 1)
    # print(true)
  fake = np.zeros((batch_size, 1))  # 0으로 라벨링
    # print(fake.shape)     # (32, 1)
    # print(fake)

  d_loss_list = list()
  g_loss_list = list()

  for i in range(epoch):
        # [1] 실제 데이터를 판별자에 입력하는 부분입니다.
        idx = np.random.randint(0, X_train.shape[0], batch_size)    
            # 0부터 X_train.shape[0] 까지 batch_size개의 랜덤 값(정수형)을 반환한다.
            # print(idx.shape)        # (32,) == (batch_size, )
            # print(idx)
        imgs = X_train[idx]
            # print(imgs.shape)   # (32, 56, 56, 1)
            # print(imgs)

            # 실제 데이터 이미지 확인하기
            # imgs = np.array(imgs[0])
            # imgs = np.reshape(imgs,(128, 173))
            # print(imgs.shape)         # (128, 173)
            # plt.imshow(imgs,'gray')
            # plt.show()

            # batch_size : 한 에폭당 생성되는 이미지의 개수

        d_loss_real = discriminator.train_on_batch(imgs, true)
            # train_on_batch : fit() 과 유사한 기능을 함
            # fit()과 차이점 : 고정된 batch_size에 신경쓰지 않는다. 
            # generator는 매번 새로운 image를 전달해야 하기 때문에 새로운 데이터를 학습해야 한다.
            # 현재 전달받은 데이터를 활용해서 가중치를 계산한다.

       # [2] 가상 이미지를 판별자에 입력하는 부분입니다.
        noise = np.random.normal(0, 1, (batch_size, nosie_size))   
            # 평균이 0, 분산이 1인 표준 정규분포, 랜덤한 값을 반환해준다.
            # (batch_size, 100) 행렬로 반환
            # print(noise.shape)  # (32, 100)
            # print(noise)
        gen_imgs = generator.predict(noise)
            # print(gen_imgs.shape)     # (32, 56, 56, 1)
            # print(gen_imgs)

            # 실제 데이터 이미지 확인하기
            # gen_imgs = np.array(gen_imgs[0])
            # gen_imgs = np.reshape(gen_imgs,(28, 28))
            # print(gen_imgs.shape)           # (28, 28)
            # plt.imshow(gen_imgs,'gray')
            # plt.show()
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

        #판별자와 생성자의 오차를 계산합니다.
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 판별자 loss
        g_loss = gan.train_on_batch(noise, true)        # 생성자 loss
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # loss 값 저장하기
        d_loss_list.append(float(d_loss))
        g_loss_list.append(float(g_loss))

        # pandas dataframe
        d_loss_df = pd.DataFrame(d_loss_list)
        g_loss_df = pd.DataFrame(g_loss_list)

        d_loss_df.columns = ['d_loss']
        g_loss_df.columns = ['g_loss']

        gd_loss_df = pd.concat([d_loss_df, g_loss_df], axis = 1)

        gd_loss_df.to_csv('C:\\nmb\\nmb_data\\gan_image\\csv\\dcgan_softmax.csv', index = False)

        if i % saving_interval == 0:
            # saving_interval 마다 이미지를 출력한다.
            noise = np.random.normal(0, 1, (25, nosie_size))
                # print(noise.shape)  # (25, 100)
            gen_imgs = generator.predict(noise)
                # print(gen_imgs.shape)   # (25, 28, 28, 1)
            # idx2 = np.random.randint(0, gen_imgs.shape[0])
            idx2 = 5    # 출력 값 고정
            print("id2 > ", idx2)
            
            gen_imgs = 0.5 * gen_imgs + 0.5
                # Rescale images 0 - 1
            print(gen_imgs.shape) # (25, 32, 128, 1)
       
            # 다시 melspectrogram으로 바꾸기 (shape 맞추기)
            gen_mels = cv2.resize(gen_imgs[idx2], (862,128))
            # gen_mels = cv2.resize(gen_imgs[idx2], (128, 862))
            # print(gen_mels.shape) # (862, 128)
            # gen_mels = gen_mels.reshape(gen_mels.shape[1], gen_mels.shape[0] )
            print(gen_mels.shape) # (128, 862)

            # 다시 melspectrogram으로 바꾸기
            remels = librosa.feature.inverse.mel_to_audio (gen_mels, sr=22050, hop_length=128, n_fft=512)
            print(remels.shape)   # (110208,)

            sf.write(f'C:\\nmb\\nmb_data\\gan_image\\softmax\\{i}.wav', remels, 22050)

            # librosa.display.waveplot(remels, 22050)
            # plt.show()
            print("end")
            

gan_train(epochs, batch, 500)


end = datetime.now()
time = end - start
print("작업 시간 : " , time)
# Out:
# ss:0.0000
# epoch:972  d_loss:0.0000  g_loss:0.0000
# epoch:973  d_loss:0.0000  g_loss:0.0000
# epoch:974  d_loss:0.0000  g_loss:0.0000
# epoch:975  d_loss:0.0000  g_loss:0.0000
# epoch:976  d_loss:0.0000  g_loss:0.0000
# epoch:977  d_loss:0.0000  g_loss:0.0000
# epoch:978  d_loss:0.0000  g_loss:0.0000
# epoch:979  d_loss:0.0000  g_loss:0.0000
# epoch:980  d_loss:0.0000  g_loss:0.0000
# epoch:981  d_loss:0.0000  g_loss:0.0000
# epoch:982  d_loss:0.0000  g_loss:0.0000
# epoch:983  d_loss:0.0000  g_loss:0.0000
# epoch:984  d_loss:0.0000  g_loss:0.0000
# epoch:985  d_loss:0.0000  g_loss:0.0000
# epoch:986  d_loss:0.0000  g_loss:0.0000
# epoch:987  d_loss:0.0000  g_loss:0.0000
# epoch:988  d_loss:0.0000  g_loss:0.0000
# epoch:989  d_loss:0.0000  g_loss:0.0000
# epoch:990  d_loss:0.0000  g_loss:0.0000
# epoch:991  d_loss:0.0000  g_loss:0.0000
# epoch:992  d_loss:0.0000  g_loss:0.0000
# epoch:993  d_loss:0.0000  g_loss:0.0000
# epoch:994  d_loss:0.0000  g_loss:0.0000
# epoch:995  d_loss:0.0000  g_loss:0.0000
# epoch:996  d_loss:0.0000  g_loss:0.0000
# epoch:997  d_loss:0.0000  g_loss:0.0000
# epoch:998  d_loss:0.0000  g_loss:0.0000
# epoch:999  d_loss:0.0000  g_loss:0.0000
# epoch:1000  d_loss:0.0000  g_loss:0.0000
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# epoch:1001  d_loss:0.0000  g_loss:0.0000
# epoch:1002  d_loss:0.0000  g_loss:0.0000
# epoch:1003  d_loss:0.0000  g_loss:0.0000
# epoch:1004  d_loss:0.0000  g_loss:0.0000
# epoch:1005  d_loss:0.0000  g_loss:0.0000
# epoch:1006  d_loss:0.0000  g_loss:0.0000
# epoch:1007  d_loss:0.0000  g_loss:0.0000
# epoch:1008  d_loss:0.0000  g_loss:0.0000
# epoch:1009  d_loss:0.0000  g_loss:0.0000
# epoch:1010  d_loss:0.0000  g_loss:0.0000
# epoch:1011  d_loss:0.0000  g_loss:0.0000
# epoch:1012  d_loss:0.0000  g_loss:0.0000
# epoch:1013  d_loss:0.0000  g_loss:0.0000
# epoch:1014  d_loss:0.0000  g_loss:0.0000
# epoch:1015  d_loss:0.0000  g_loss:0.0000
# epoch:1016  d_loss:0.0000  g_loss:0.0000
# epoch:1017  d_loss:0.0000  g_loss:0.0000
# epoch:1018  d_loss:0.0000  g_loss:0.0000
# epoch:1019  d_loss:0.0000  g_loss:0.0000
# epoch:1020  d_loss:0.0000  g_loss:0.0000
# epoch:1021  d_loss:0.0000  g_loss:0.0000
# epoch:1022  d_loss:0.0000  g_loss:0.0000
# epoch:1023  d_loss:0.0000  g_loss:0.0000
# epoch:1024  d_loss:0.0000  g_loss:0.0000
# epoch:1025  d_loss:0.0000  g_loss:0.0000
# epoch:1026  d_loss:0.0000  g_loss:0.0000
# epoch:1027  d_loss:0.0000  g_loss:0.0000
# epoch:1028  d_loss:0.0000  g_loss:0.0000
# epoch:1029  d_loss:0.0000  g_loss:0.0000
# epoch:1030  d_loss:0.0000  g_loss:0.0000
# epoch:1031  d_loss:0.0000  g_loss:0.0000
# epoch:1032  d_loss:0.0000  g_loss:0.0000
# epoch:1033  d_loss:0.0000  g_loss:0.0000
# epoch:1034  d_loss:0.0000  g_loss:0.0000
# epoch:1035  d_loss:0.0000  g_loss:0.0000
# epoch:1036  d_loss:0.0000  g_loss:0.0000
# epoch:1037  d_loss:0.0000  g_loss:0.0000
# epoch:1038  d_loss:0.0000  g_loss:0.0000
# epoch:1039  d_loss:0.0000  g_loss:0.0000
# epoch:1040  d_loss:0.0000  g_loss:0.0000
# epoch:1041  d_loss:0.0000  g_loss:0.0000
# epoch:1042  d_loss:0.0000  g_loss:0.0000
# epoch:1043  d_loss:0.0000  g_loss:0.0000
# epoch:1044  d_loss:0.0000  g_loss:0.0000
# epoch:1045  d_loss:0.0000  g_loss:0.0000
# epoch:1046  d_loss:0.0000  g_loss:0.0000
# epoch:1047  d_loss:0.0000  g_loss:0.0000
# epoch:1048  d_loss:0.0000  g_loss:0.0000
# epoch:1049  d_loss:0.0000  g_loss:0.0000
# epoch:1050  d_loss:0.0000  g_loss:0.0000
# epoch:1051  d_loss:0.0000  g_loss:0.0000
# epoch:1052  d_loss:0.0000  g_loss:0.0000
# epoch:1053  d_loss:0.0000  g_loss:0.0000
# epoch:1054  d_loss:0.0000  g_loss:0.0000
# epoch:1055  d_loss:0.0000  g_loss:0.0000
# epoch:1056  d_loss:0.0000  g_loss:0.0000
# epoch:1057  d_loss:0.0000  g_loss:0.0000
# epoch:1058  d_loss:0.0000  g_loss:0.0000
# epoch:1059  d_loss:0.0000  g_loss:0.0000
# epoch:1060  d_loss:0.0000  g_loss:0.0000
# epoch:1061  d_loss:0.0000  g_loss:0.0000
# epoch:1062  d_loss:0.0000  g_loss:0.0000
# epoch:1063  d_loss:0.0000  g_loss:0.0000
# epoch:1064  d_loss:0.0000  g_loss:0.0000
# epoch:1065  d_loss:0.0000  g_loss:0.0000
# epoch:1066  d_loss:0.0000  g_loss:0.0000
# epoch:1067  d_loss:0.0000  g_loss:0.0000
# epoch:1068  d_loss:0.0000  g_loss:0.0000
# epoch:1069  d_loss:0.0000  g_loss:0.0000
# epoch:1070  d_loss:0.0000  g_loss:0.0000
# epoch:1071  d_loss:0.0000  g_loss:0.0000
# epoch:1072  d_loss:0.0000  g_loss:0.0000
# epoch:1073  d_loss:0.0000  g_loss:0.0000
# epoch:1074  d_loss:0.0000  g_loss:0.0000
# epoch:1075  d_loss:0.0000  g_loss:0.0000
# epoch:1076  d_loss:0.0000  g_loss:0.0000
# epoch:1077  d_loss:0.0000  g_loss:0.0000
# epoch:1078  d_loss:0.0000  g_loss:0.0000
# epoch:1079  d_loss:0.0000  g_loss:0.0000
# epoch:1080  d_loss:0.0000  g_loss:0.0000
# epoch:1081  d_loss:0.0000  g_loss:0.0000
# epoch:1082  d_loss:0.0000  g_loss:0.0000
# epoch:1083  d_loss:0.0000  g_loss:0.0000
# epoch:1084  d_loss:0.0000  g_loss:0.0000
# epoch:1085  d_loss:0.0000  g_loss:0.0000
# epoch:1086  d_loss:0.0000  g_loss:0.0000
# epoch:1087  d_loss:0.0000  g_loss:0.0000
# epoch:1088  d_loss:0.0000  g_loss:0.0000
# epoch:1089  d_loss:0.0000  g_loss:0.0000
# epoch:1090  d_loss:0.0000  g_loss:0.0000
# epoch:1091  d_loss:0.0000  g_loss:0.0000
# epoch:1092  d_loss:0.0000  g_loss:0.0000
# epoch:1093  d_loss:0.0000  g_loss:0.0000
# epoch:1094  d_loss:0.0000  g_loss:0.0000
# epoch:1095  d_loss:0.0000  g_loss:0.0000
# epoch:1096  d_loss:0.0000  g_loss:0.0000
# epoch:1097  d_loss:0.0000  g_loss:0.0000
# epoch:1098  d_loss:0.0000  g_loss:0.0000
# epoch:1099  d_loss:0.0000  g_loss:0.0000
# epoch:1100  d_loss:0.0000  g_loss:0.0000
# epoch:1101  d_loss:0.0000  g_loss:0.0000
# epoch:1102  d_loss:0.0000  g_loss:0.0000
# epoch:1103  d_loss:0.0000  g_loss:0.0000
# epoch:1104  d_loss:0.0000  g_loss:0.0000
# epoch:1105  d_loss:0.0000  g_loss:0.0000
# epoch:1106  d_loss:0.0000  g_loss:0.0000
# epoch:1107  d_loss:0.0000  g_loss:0.0000
# epoch:1108  d_loss:0.0000  g_loss:0.0000
# epoch:1109  d_loss:0.0000  g_loss:0.0000
# epoch:1110  d_loss:0.0000  g_loss:0.0000
# epoch:1111  d_loss:0.0000  g_loss:0.0000
# epoch:1112  d_loss:0.0000  g_loss:0.0000
# epoch:1113  d_loss:0.0000  g_loss:0.0000
# epoch:1114  d_loss:0.0000  g_loss:0.0000
# epoch:1115  d_loss:0.0000  g_loss:0.0000
# epoch:1116  d_loss:0.0000  g_loss:0.0000
# epoch:1117  d_loss:0.0000  g_loss:0.0000
# epoch:1118  d_loss:0.0000  g_loss:0.0000
# epoch:1119  d_loss:0.0000  g_loss:0.0000
# epoch:1120  d_loss:0.0000  g_loss:0.0000
# epoch:1121  d_loss:0.0000  g_loss:0.0000
# epoch:1122  d_loss:0.0000  g_loss:0.0000
# epoch:1123  d_loss:0.0000  g_loss:0.0000
# epoch:1124  d_loss:0.0000  g_loss:0.0000
# epoch:1125  d_loss:0.0000  g_loss:0.0000
# epoch:1126  d_loss:0.0000  g_loss:0.0000
# epoch:1127  d_loss:0.0000  g_loss:0.0000
# epoch:1128  d_loss:0.0000  g_loss:0.0000
# epoch:1129  d_loss:0.0000  g_loss:0.0000
# epoch:1130  d_loss:0.0000  g_loss:0.0000
# epoch:1131  d_loss:0.0000  g_loss:0.0000
# epoch:1132  d_loss:0.0000  g_loss:0.0000
# epoch:1133  d_loss:0.0000  g_loss:0.0000
# epoch:1134  d_loss:0.0000  g_loss:0.0000
# epoch:1135  d_loss:0.0000  g_loss:0.0000
# epoch:1136  d_loss:0.0000  g_loss:0.0000
# epoch:1137  d_loss:0.0000  g_loss:0.0000
# epoch:1138  d_loss:0.0000  g_loss:0.0000
# epoch:1139  d_loss:0.0000  g_loss:0.0000
# epoch:1140  d_loss:0.0000  g_loss:0.0000
# epoch:1141  d_loss:0.0000  g_loss:0.0000
# epoch:1142  d_loss:0.0000  g_loss:0.0000
# epoch:1143  d_loss:0.0000  g_loss:0.0000
# epoch:1144  d_loss:0.0000  g_loss:0.0000
# epoch:1145  d_loss:0.0000  g_loss:0.0000
# epoch:1146  d_loss:0.0000  g_loss:0.0000
# epoch:1147  d_loss:0.0000  g_loss:0.0000
# epoch:1148  d_loss:0.0000  g_loss:0.0000
# epoch:1149  d_loss:0.0000  g_loss:0.0000
# epoch:1150  d_loss:0.0000  g_loss:0.0000
# epoch:1151  d_loss:0.0000  g_loss:0.0000
# epoch:1152  d_loss:0.0000  g_loss:0.0000
# epoch:1153  d_loss:0.0000  g_loss:0.0000
# epoch:1154  d_loss:0.0000  g_loss:0.0000
# epoch:1155  d_loss:0.0000  g_loss:0.0000
# epoch:1156  d_loss:0.0000  g_loss:0.0000
# epoch:1157  d_loss:0.0000  g_loss:0.0000
# epoch:1158  d_loss:0.0000  g_loss:0.0000
# epoch:1159  d_loss:0.0000  g_loss:0.0000
# epoch:1160  d_loss:0.0000  g_loss:0.0000
# epoch:1161  d_loss:0.0000  g_loss:0.0000
# epoch:1162  d_loss:0.0000  g_loss:0.0000
# epoch:1163  d_loss:0.0000  g_loss:0.0000
# epoch:1164  d_loss:0.0000  g_loss:0.0000
# epoch:1165  d_loss:0.0000  g_loss:0.0000
# epoch:1166  d_loss:0.0000  g_loss:0.0000
# epoch:1167  d_loss:0.0000  g_loss:0.0000
# epoch:1168  d_loss:0.0000  g_loss:0.0000
# epoch:1169  d_loss:0.0000  g_loss:0.0000
# epoch:1170  d_loss:0.0000  g_loss:0.0000
# epoch:1171  d_loss:0.0000  g_loss:0.0000
# epoch:1172  d_loss:0.0000  g_loss:0.0000
# epoch:1173  d_loss:0.0000  g_loss:0.0000
# epoch:1174  d_loss:0.0000  g_loss:0.0000
# epoch:1175  d_loss:0.0000  g_loss:0.0000
# epoch:1176  d_loss:0.0000  g_loss:0.0000
# epoch:1177  d_loss:0.0000  g_loss:0.0000
# epoch:1178  d_loss:0.0000  g_loss:0.0000
# epoch:1179  d_loss:0.0000  g_loss:0.0000
# epoch:1180  d_loss:0.0000  g_loss:0.0000
# epoch:1181  d_loss:0.0000  g_loss:0.0000
# epoch:1182  d_loss:0.0000  g_loss:0.0000
# epoch:1183  d_loss:0.0000  g_loss:0.0000
# epoch:1184  d_loss:0.0000  g_loss:0.0000
# epoch:1185  d_loss:0.0000  g_loss:0.0000
# epoch:1186  d_loss:0.0000  g_loss:0.0000
# epoch:1187  d_loss:0.0000  g_loss:0.0000
# epoch:1188  d_loss:0.0000  g_loss:0.0000
# epoch:1189  d_loss:0.0000  g_loss:0.0000
# epoch:1190  d_loss:0.0000  g_loss:0.0000
# epoch:1191  d_loss:0.0000  g_loss:0.0000
# epoch:1192  d_loss:0.0000  g_loss:0.0000
# epoch:1193  d_loss:0.0000  g_loss:0.0000
# epoch:1194  d_loss:0.0000  g_loss:0.0000
# epoch:1195  d_loss:0.0000  g_loss:0.0000
# epoch:1196  d_loss:0.0000  g_loss:0.0000
# epoch:1197  d_loss:0.0000  g_loss:0.0000
# epoch:1198  d_loss:0.0000  g_loss:0.0000
# epoch:1199  d_loss:0.0000  g_loss:0.0000
# epoch:1200  d_loss:0.0000  g_loss:0.0000
# epoch:1201  d_loss:0.0000  g_loss:0.0000
# epoch:1202  d_loss:0.0000  g_loss:0.0000
# epoch:1203  d_loss:0.0000  g_loss:0.0000
# epoch:1204  d_loss:0.0000  g_loss:0.0000
# epoch:1205  d_loss:0.0000  g_loss:0.0000
# epoch:1206  d_loss:0.0000  g_loss:0.0000
# epoch:1207  d_loss:0.0000  g_loss:0.0000
# epoch:1208  d_loss:0.0000  g_loss:0.0000
# epoch:1209  d_loss:0.0000  g_loss:0.0000
# epoch:1210  d_loss:0.0000  g_loss:0.0000
# epoch:1211  d_loss:0.0000  g_loss:0.0000
# epoch:1212  d_loss:0.0000  g_loss:0.0000
# epoch:1213  d_loss:0.0000  g_loss:0.0000
# epoch:1214  d_loss:0.0000  g_loss:0.0000
# epoch:1215  d_loss:0.0000  g_loss:0.0000
# epoch:1216  d_loss:0.0000  g_loss:0.0000
# epoch:1217  d_loss:0.0000  g_loss:0.0000
# epoch:1218  d_loss:0.0000  g_loss:0.0000
# epoch:1219  d_loss:0.0000  g_loss:0.0000
# epoch:1220  d_loss:0.0000  g_loss:0.0000
# epoch:1221  d_loss:0.0000  g_loss:0.0000
# epoch:1222  d_loss:0.0000  g_loss:0.0000
# epoch:1223  d_loss:0.0000  g_loss:0.0000
# epoch:1224  d_loss:0.0000  g_loss:0.0000
# epoch:1225  d_loss:0.0000  g_loss:0.0000
# epoch:1226  d_loss:0.0000  g_loss:0.0000
# epoch:1227  d_loss:0.0000  g_loss:0.0000
# epoch:1228  d_loss:0.0000  g_loss:0.0000
# epoch:1229  d_loss:0.0000  g_loss:0.0000
# epoch:1230  d_loss:0.0000  g_loss:0.0000
# epoch:1231  d_loss:0.0000  g_loss:0.0000
# epoch:1232  d_loss:0.0000  g_loss:0.0000
# epoch:1233  d_loss:0.0000  g_loss:0.0000
# epoch:1234  d_loss:0.0000  g_loss:0.0000
# epoch:1235  d_loss:0.0000  g_loss:0.0000
# epoch:1236  d_loss:0.0000  g_loss:0.0000
# epoch:1237  d_loss:0.0000  g_loss:0.0000
# epoch:1238  d_loss:0.0000  g_loss:0.0000
# epoch:1239  d_loss:0.0000  g_loss:0.0000
# epoch:1240  d_loss:0.0000  g_loss:0.0000
# epoch:1241  d_loss:0.0000  g_loss:0.0000
# epoch:1242  d_loss:0.0000  g_loss:0.0000
# epoch:1243  d_loss:0.0000  g_loss:0.0000
# epoch:1244  d_loss:0.0000  g_loss:0.0000
# epoch:1245  d_loss:0.0000  g_loss:0.0000
# epoch:1246  d_loss:0.0000  g_loss:0.0000
# epoch:1247  d_loss:0.0000  g_loss:0.0000
# epoch:1248  d_loss:0.0000  g_loss:0.0000
# epoch:1249  d_loss:0.0000  g_loss:0.0000
# epoch:1250  d_loss:0.0000  g_loss:0.0000
# epoch:1251  d_loss:0.0000  g_loss:0.0000
# epoch:1252  d_loss:0.0000  g_loss:0.0000
# epoch:1253  d_loss:0.0000  g_loss:0.0000
# epoch:1254  d_loss:0.0000  g_loss:0.0000
# epoch:1255  d_loss:0.0000  g_loss:0.0000
# epoch:1256  d_loss:0.0000  g_loss:0.0000
# epoch:1257  d_loss:0.0000  g_loss:0.0000
# epoch:1258  d_loss:0.0000  g_loss:0.0000
# epoch:1259  d_loss:0.0000  g_loss:0.0000
# epoch:1260  d_loss:0.0000  g_loss:0.0000
# epoch:1261  d_loss:0.0000  g_loss:0.0000
# epoch:1262  d_loss:0.0000  g_loss:0.0000
# epoch:1263  d_loss:0.0000  g_loss:0.0000
# epoch:1264  d_loss:0.0000  g_loss:0.0000
# epoch:1265  d_loss:0.0000  g_loss:0.0000
# epoch:1266  d_loss:0.0000  g_loss:0.0000
# epoch:1267  d_loss:0.0000  g_loss:0.0000
# epoch:1268  d_loss:0.0000  g_loss:0.0000
# epoch:1269  d_loss:0.0000  g_loss:0.0000
# epoch:1270  d_loss:0.0000  g_loss:0.0000
# epoch:1271  d_loss:0.0000  g_loss:0.0000
# epoch:1272  d_loss:0.0000  g_loss:0.0000
# epoch:1273  d_loss:0.0000  g_loss:0.0000
# epoch:1274  d_loss:0.0000  g_loss:0.0000
# epoch:1275  d_loss:0.0000  g_loss:0.0000
# epoch:1276  d_loss:0.0000  g_loss:0.0000
# epoch:1277  d_loss:0.0000  g_loss:0.0000
# epoch:1278  d_loss:0.0000  g_loss:0.0000
# epoch:1279  d_loss:0.0000  g_loss:0.0000
# epoch:1280  d_loss:0.0000  g_loss:0.0000
# epoch:1281  d_loss:0.0000  g_loss:0.0000
# epoch:1282  d_loss:0.0000  g_loss:0.0000
# epoch:1283  d_loss:0.0000  g_loss:0.0000
# epoch:1284  d_loss:0.0000  g_loss:0.0000
# epoch:1285  d_loss:0.0000  g_loss:0.0000
# epoch:1286  d_loss:0.0000  g_loss:0.0000
# epoch:1287  d_loss:0.0000  g_loss:0.0000
# epoch:1288  d_loss:0.0000  g_loss:0.0000
# epoch:1289  d_loss:0.0000  g_loss:0.0000
# epoch:1290  d_loss:0.0000  g_loss:0.0000
# epoch:1291  d_loss:0.0000  g_loss:0.0000
# epoch:1292  d_loss:0.0000  g_loss:0.0000
# epoch:1293  d_loss:0.0000  g_loss:0.0000
# epoch:1294  d_loss:0.0000  g_loss:0.0000
# epoch:1295  d_loss:0.0000  g_loss:0.0000
# epoch:1296  d_loss:0.0000  g_loss:0.0000
# epoch:1297  d_loss:0.0000  g_loss:0.0000
# epoch:1298  d_loss:0.0000  g_loss:0.0000
# epoch:1299  d_loss:0.0000  g_loss:0.0000
# epoch:1300  d_loss:0.0000  g_loss:0.0000
# epoch:1301  d_loss:0.0000  g_loss:0.0000
# epoch:1302  d_loss:0.0000  g_loss:0.0000
# epoch:1303  d_loss:0.0000  g_loss:0.0000
# epoch:1304  d_loss:0.0000  g_loss:0.0000
# epoch:1305  d_loss:0.0000  g_loss:0.0000
# epoch:1306  d_loss:0.0000  g_loss:0.0000
# epoch:1307  d_loss:0.0000  g_loss:0.0000
# epoch:1308  d_loss:0.0000  g_loss:0.0000
# epoch:1309  d_loss:0.0000  g_loss:0.0000
# epoch:1310  d_loss:0.0000  g_loss:0.0000
# epoch:1311  d_loss:0.0000  g_loss:0.0000
# epoch:1312  d_loss:0.0000  g_loss:0.0000
# epoch:1313  d_loss:0.0000  g_loss:0.0000
# epoch:1314  d_loss:0.0000  g_loss:0.0000
# epoch:1315  d_loss:0.0000  g_loss:0.0000
# epoch:1316  d_loss:0.0000  g_loss:0.0000
# epoch:1317  d_loss:0.0000  g_loss:0.0000
# epoch:1318  d_loss:0.0000  g_loss:0.0000
# epoch:1319  d_loss:0.0000  g_loss:0.0000
# epoch:1320  d_loss:0.0000  g_loss:0.0000
# epoch:1321  d_loss:0.0000  g_loss:0.0000
# epoch:1322  d_loss:0.0000  g_loss:0.0000
# epoch:1323  d_loss:0.0000  g_loss:0.0000
# epoch:1324  d_loss:0.0000  g_loss:0.0000
# epoch:1325  d_loss:0.0000  g_loss:0.0000
# epoch:1326  d_loss:0.0000  g_loss:0.0000
# epoch:1327  d_loss:0.0000  g_loss:0.0000
# epoch:1328  d_loss:0.0000  g_loss:0.0000
# epoch:1329  d_loss:0.0000  g_loss:0.0000
# epoch:1330  d_loss:0.0000  g_loss:0.0000
# epoch:1331  d_loss:0.0000  g_loss:0.0000
# epoch:1332  d_loss:0.0000  g_loss:0.0000
# epoch:1333  d_loss:0.0000  g_loss:0.0000
# epoch:1334  d_loss:0.0000  g_loss:0.0000
# epoch:1335  d_loss:0.0000  g_loss:0.0000
# epoch:1336  d_loss:0.0000  g_loss:0.0000
# epoch:1337  d_loss:0.0000  g_loss:0.0000
# epoch:1338  d_loss:0.0000  g_loss:0.0000
# epoch:1339  d_loss:0.0000  g_loss:0.0000
# epoch:1340  d_loss:0.0000  g_loss:0.0000
# epoch:1341  d_loss:0.0000  g_loss:0.0000
# epoch:1342  d_loss:0.0000  g_loss:0.0000
# epoch:1343  d_loss:0.0000  g_loss:0.0000
# epoch:1344  d_loss:0.0000  g_loss:0.0000
# epoch:1345  d_loss:0.0000  g_loss:0.0000
# epoch:1346  d_loss:0.0000  g_loss:0.0000
# epoch:1347  d_loss:0.0000  g_loss:0.0000
# epoch:1348  d_loss:0.0000  g_loss:0.0000
# epoch:1349  d_loss:0.0000  g_loss:0.0000
# epoch:1350  d_loss:0.0000  g_loss:0.0000
# epoch:1351  d_loss:0.0000  g_loss:0.0000
# epoch:1352  d_loss:0.0000  g_loss:0.0000
# epoch:1353  d_loss:0.0000  g_loss:0.0000
# epoch:1354  d_loss:0.0000  g_loss:0.0000
# epoch:1355  d_loss:0.0000  g_loss:0.0000
# epoch:1356  d_loss:0.0000  g_loss:0.0000
# epoch:1357  d_loss:0.0000  g_loss:0.0000
# epoch:1358  d_loss:0.0000  g_loss:0.0000
# epoch:1359  d_loss:0.0000  g_loss:0.0000
# epoch:1360  d_loss:0.0000  g_loss:0.0000
# epoch:1361  d_loss:0.0000  g_loss:0.0000
# epoch:1362  d_loss:0.0000  g_loss:0.0000
# epoch:1363  d_loss:0.0000  g_loss:0.0000
# epoch:1364  d_loss:0.0000  g_loss:0.0000
# epoch:1365  d_loss:0.0000  g_loss:0.0000
# epoch:1366  d_loss:0.0000  g_loss:0.0000
# epoch:1367  d_loss:0.0000  g_loss:0.0000
# epoch:1368  d_loss:0.0000  g_loss:0.0000
# epoch:1369  d_loss:0.0000  g_loss:0.0000
# epoch:1370  d_loss:0.0000  g_loss:0.0000
# epoch:1371  d_loss:0.0000  g_loss:0.0000
# epoch:1372  d_loss:0.0000  g_loss:0.0000
# epoch:1373  d_loss:0.0000  g_loss:0.0000
# epoch:1374  d_loss:0.0000  g_loss:0.0000
# epoch:1375  d_loss:0.0000  g_loss:0.0000
# epoch:1376  d_loss:0.0000  g_loss:0.0000
# epoch:1377  d_loss:0.0000  g_loss:0.0000
# epoch:1378  d_loss:0.0000  g_loss:0.0000
# epoch:1379  d_loss:0.0000  g_loss:0.0000
# epoch:1380  d_loss:0.0000  g_loss:0.0000
# epoch:1381  d_loss:0.0000  g_loss:0.0000
# epoch:1382  d_loss:0.0000  g_loss:0.0000
# epoch:1383  d_loss:0.0000  g_loss:0.0000
# epoch:1384  d_loss:0.0000  g_loss:0.0000
# epoch:1385  d_loss:0.0000  g_loss:0.0000
# epoch:1386  d_loss:0.0000  g_loss:0.0000
# epoch:1387  d_loss:0.0000  g_loss:0.0000
# epoch:1388  d_loss:0.0000  g_loss:0.0000
# epoch:1389  d_loss:0.0000  g_loss:0.0000
# epoch:1390  d_loss:0.0000  g_loss:0.0000
# epoch:1391  d_loss:0.0000  g_loss:0.0000
# epoch:1392  d_loss:0.0000  g_loss:0.0000
# epoch:1393  d_loss:0.0000  g_loss:0.0000
# epoch:1394  d_loss:0.0000  g_loss:0.0000
# epoch:1395  d_loss:0.0000  g_loss:0.0000
# epoch:1396  d_loss:0.0000  g_loss:0.0000
# epoch:1397  d_loss:0.0000  g_loss:0.0000
# epoch:1398  d_loss:0.0000  g_loss:0.0000
# epoch:1399  d_loss:0.0000  g_loss:0.0000
# epoch:1400  d_loss:0.0000  g_loss:0.0000
# epoch:1401  d_loss:0.0000  g_loss:0.0000
# epoch:1402  d_loss:0.0000  g_loss:0.0000
# epoch:1403  d_loss:0.0000  g_loss:0.0000
# epoch:1404  d_loss:0.0000  g_loss:0.0000
# epoch:1405  d_loss:0.0000  g_loss:0.0000
# epoch:1406  d_loss:0.0000  g_loss:0.0000
# epoch:1407  d_loss:0.0000  g_loss:0.0000
# epoch:1408  d_loss:0.0000  g_loss:0.0000
# epoch:1409  d_loss:0.0000  g_loss:0.0000
# epoch:1410  d_loss:0.0000  g_loss:0.0000
# epoch:1411  d_loss:0.0000  g_loss:0.0000
# epoch:1412  d_loss:0.0000  g_loss:0.0000
# epoch:1413  d_loss:0.0000  g_loss:0.0000
# epoch:1414  d_loss:0.0000  g_loss:0.0000
# epoch:1415  d_loss:0.0000  g_loss:0.0000
# epoch:1416  d_loss:0.0000  g_loss:0.0000
# epoch:1417  d_loss:0.0000  g_loss:0.0000
# epoch:1418  d_loss:0.0000  g_loss:0.0000
# epoch:1419  d_loss:0.0000  g_loss:0.0000
# epoch:1420  d_loss:0.0000  g_loss:0.0000
# epoch:1421  d_loss:0.0000  g_loss:0.0000
# epoch:1422  d_loss:0.0000  g_loss:0.0000
# epoch:1423  d_loss:0.0000  g_loss:0.0000
# epoch:1424  d_loss:0.0000  g_loss:0.0000
# epoch:1425  d_loss:0.0000  g_loss:0.0000
# epoch:1426  d_loss:0.0000  g_loss:0.0000
# epoch:1427  d_loss:0.0000  g_loss:0.0000
# epoch:1428  d_loss:0.0000  g_loss:0.0000
# epoch:1429  d_loss:0.0000  g_loss:0.0000
# epoch:1430  d_loss:0.0000  g_loss:0.0000
# epoch:1431  d_loss:0.0000  g_loss:0.0000
# epoch:1432  d_loss:0.0000  g_loss:0.0000
# epoch:1433  d_loss:0.0000  g_loss:0.0000
# epoch:1434  d_loss:0.0000  g_loss:0.0000
# epoch:1435  d_loss:0.0000  g_loss:0.0000
# epoch:1436  d_loss:0.0000  g_loss:0.0000
# epoch:1437  d_loss:0.0000  g_loss:0.0000
# epoch:1438  d_loss:0.0000  g_loss:0.0000
# epoch:1439  d_loss:0.0000  g_loss:0.0000
# epoch:1440  d_loss:0.0000  g_loss:0.0000
# epoch:1441  d_loss:0.0000  g_loss:0.0000
# epoch:1442  d_loss:0.0000  g_loss:0.0000
# epoch:1443  d_loss:0.0000  g_loss:0.0000
# epoch:1444  d_loss:0.0000  g_loss:0.0000
# epoch:1445  d_loss:0.0000  g_loss:0.0000
# epoch:1446  d_loss:0.0000  g_loss:0.0000
# epoch:1447  d_loss:0.0000  g_loss:0.0000
# epoch:1448  d_loss:0.0000  g_loss:0.0000
# epoch:1449  d_loss:0.0000  g_loss:0.0000
# epoch:1450  d_loss:0.0000  g_loss:0.0000
# epoch:1451  d_loss:0.0000  g_loss:0.0000
# epoch:1452  d_loss:0.0000  g_loss:0.0000
# epoch:1453  d_loss:0.0000  g_loss:0.0000
# epoch:1454  d_loss:0.0000  g_loss:0.0000
# epoch:1455  d_loss:0.0000  g_loss:0.0000
# epoch:1456  d_loss:0.0000  g_loss:0.0000
# epoch:1457  d_loss:0.0000  g_loss:0.0000
# epoch:1458  d_loss:0.0000  g_loss:0.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-32e90c2d6bb4> in <module>
#     129
#     130
# --> 131 gan_train(epochs, batch, 500)
#     132
#     133
#
# <ipython-input-7-32e90c2d6bb4> in gan_train(epoch, batch_size, saving_interval)
#      79         #판별자와 생성자의 오차를 계산합니다.
#      80         d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 판별자 loss
# ---> 81         g_loss = gan.train_on_batch(noise, true)        # 생성자 loss
#      82         print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)
#      83
#
# ~\anaconda3\envs\nmb\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1829     with self.distribute_strategy.scope(), \
#    1830          training_utils.RespectCompiledTrainableState(self):
# -> 1831       iterator = data_adapter.single_batch_iterator(self.distribute_strategy, x,
#    1832                                                     y, sample_weight,
#    1833                                                     class_weight)
#
# ~\anaconda3\envs\nmb\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in single_batch_iterator(strategy, x, y, sample_weight, class_weight)
#    1626     dataset = dataset.map(_make_class_weight_map_fn(class_weight))
#    1627   dataset = strategy.experimental_distribute_dataset(dataset)
# -> 1628   return iter(dataset)
#    1629
#    1630
#
# ~\anaconda3\envs\nmb\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __iter__(self)
#     407     if context.executing_eagerly() or ops.inside_function():
#     408       with ops.colocate_with(self._variant_tensor):
# --> 409         return iterator_ops.OwnedIterator(self)
#     410     else:
#     411       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# ~\anaconda3\envs\nmb\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in __init__(self, dataset, components, element_spec)
#     694       if (components is not None or element_spec is not None):
#     695         raise ValueError(error_message)
# --> 696       self._create_iterator(dataset)
#     697
#     698   def _create_iterator(self, dataset):
#
# ~\anaconda3\envs\nmb\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in _create_iterator(self, dataset)
#     717               output_types=self._flat_output_types,
#     718               output_shapes=self._flat_output_shapes))
# --> 719       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     720       # Delete the resource when this object is deleted
#     721       self._resource_deleter = IteratorResourceDeleter(
#
# ~\anaconda3\envs\nmb\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3117   if tld.is_eager:
#    3118     try:
# -> 3119       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3120         _ctx, "MakeIterator", name, dataset, iterator)
#    3121       return _result
#
# KeyboardInterrupt:

# %%
loss_csv = pd.read_csv('C:\\nmb\\nmb_data\\gan_image\\csv\\dcgan_softmax.csv')
# print(loss_csv)
# print(loss_csv.shape)
 
# generator loss
plt.plot(loss_csv['g_loss'])

plt.title(epochs-1)
plt.show()

# %%
# discriminator loss
plt.plot(loss_csv['d_loss'], color='orange')

plt.title(epochs-1)
plt.show()
